# %% [markdown]
# ## Image-Based LLaMA Inference Script

# %% [markdown]
# ### Define Variables

# %%
# Inputs to model: Prompt, # ex, which ref examples
PATH_TO_GUIDE_PROMPT = "../prompts/6_29_25_EHP6_targeted_with_images.txt"
MODE = "TGT_RECAP"
NUM_REF_EXS_TO_USE = 1
TRAIN_TO_REF_IDX_FILE_PATH = '../data/img_similarities_bw_train_and_ref.pkl'
# Double-check this path
EXAMPLE_FORMAT = "Example:\n\tInput: {inp}\n\tOutput: {out}\n"

# For LLaMA response dictionary
LOAD_IN_PROGRESS_LLAMA_DICT = True

# Output: LLaMA responses
OUT_PATH = '../summer_llama_output/img_p' + MODE + '_llama_responses_' + str(NUM_REF_EXS_TO_USE) + '_' + PATH_TO_GUIDE_PROMPT.split('/')[-1][:-4] + '.pkl'
print(OUT_PATH)



# There is a training set of English images/captions to be "recaptioned" before translation
# There is a reference set of paired images/captions written from En and Ja speakers
# Ja captions have been translated to English with Google Translate
TRAIN_IDS = '../data/ids_train.en1'
TRAIN_CAPS = '../data/caps_train.en1'
ALL_EN_REF_IDS = ['../data/ids_ref.en1','../data/ids_ref.en2','../data/ids_ref.en3','../data/ids_ref.en4','../data/ids_ref.en5']
ALL_EN_REF_CAPS = ['../data/caps_ref.en1','../data/caps_ref.en2','../data/caps_ref.en3','../data/caps_ref.en4','../data/caps_ref.en5']
ALL_JA_REF_IDS = ['../data/ids_ref.ja1','../data/ids_ref.ja2','../data/ids_ref.ja3','../data/ids_ref.ja4','../data/ids_ref.ja5']
ALL_JA_REF_CAPS = ['../data/caps_ref.ja_to_en1','../data/caps_ref.ja_to_en2','../data/caps_ref.ja_to_en3','../data/caps_ref.ja_to_en4','../data/caps_ref.ja_to_en5']


# Model info
MODEL_TO_USE = "meta-llama/Llama-3.2-11B-Vision-Instruct"          
PATH_TO_HUGGING_FACE_KEY = '/ihome/akovashka/krb115/hf_key'

# LLM Main params
GPU_MEMORY_UTILIZATION = 0.90 
MAX_MODEL_LEN = 9192 
ENFORCE_EAGER = True
MAXS_NUM_SEQS = 20
MAX_NUMBER_BATCHED_TOKENS = 9192

# LLM Sample params
TEMPERATURE = 0 
SEED = 42
STOP_STRING = "</final>" #"}"
INCLUDE_STOP_STR_IN_OUTPUT = True
MAX_TOKENS = 448
TENSOR_PARALLEL_SIZE = 1
# Out:
# ../summer_llama_output/img_pClean2ndNeighborEH6A_llama_responses_1_6_29_25_EHP6_targeted_with_images.pkl

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pickle
import random
import torch
from PIL import Image
from transformers import MllamaForConditionalGeneration, AutoProcessor

random.seed(42)

# %%
# GPU-based imports
from vllm import LLM, SamplingParams
from huggingface_hub import login

with open(PATH_TO_HUGGING_FACE_KEY, 'r') as f:
    hf_tok = f.readlines()[0].strip()
login(hf_tok)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /ihome/akovashka/krb115/.cache/huggingface/token
# Login successful

# %% [markdown]
# ### Load training/reference image ids and captions; mention data

# %%
ja_ref_idx_to_cap_dict = dict()
en_ref_idx_to_cap_dict = dict()
train_idx_to_cap_dict = dict()

# Assign id to each ref speaker set i = 1 to 5 
for i in range(1,len(ALL_EN_REF_IDS) + 1):
    ja_ref_idx_to_cap_dict[i] = dict()
    en_ref_idx_to_cap_dict[i] = dict()

# Go through each ref path for En and create mapping dictionary
for i, (ref_cap_path, ref_id_path) in enumerate(zip(ALL_EN_REF_CAPS, ALL_EN_REF_IDS)): 
    print(i+1)
    print(ref_cap_path)
    print(ref_id_path)

    with open(ref_cap_path, 'r') as f:
        with open(ref_id_path, 'r') as g:
            en_ref_caps = [l.strip() for l in f.readlines()]
            en_ref_ids = [l.strip() for l in g.readlines()]
            for idx, cap in zip(en_ref_ids, en_ref_caps):
                en_ref_idx_to_cap_dict[i+1][idx] = cap

# Go through each ref path for Ja and create mapping dictionary
for i, (ref_cap_path, ref_id_path) in enumerate(zip(ALL_JA_REF_CAPS, ALL_JA_REF_IDS)): 
    print(i+1)
    print(ref_cap_path)
    print(ref_id_path)

    with open(ref_cap_path, 'r') as f:
        with open(ref_id_path, 'r') as g:
            ja_ref_caps = [l.strip() for l in f.readlines()]
            ja_ref_ids = [l.strip() for l in g.readlines()]
            for idx, cap in zip(ja_ref_ids, ja_ref_caps):
                ja_ref_idx_to_cap_dict[i+1][idx] = cap

# Get train dictionary
with open(TRAIN_CAPS, 'r') as f:
    with open(TRAIN_IDS, 'r') as g:
        train_caps = [l.strip() for l in f.readlines()]
        train_ids = [l.strip() for l in g.readlines()]
        for idx, cap in zip(train_ids, train_caps):
            train_idx_to_cap_dict[idx] = cap

print('Lengths')
print('# Ja Ref Caps: ' + str(len(ja_ref_caps)))
print('# En Ref Caps: ' + str(len(en_ref_caps)))
print('# En Train Caps: ' + str(len(train_caps)))
# Out:
# 1
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/caps_ref.en1
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/ids_ref.en1
# 2
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/caps_ref.en2
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/ids_ref.en2
# 3
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/caps_ref.en3
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/ids_ref.en3
# 4
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/caps_ref.en4
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/ids_ref.en4
# 5
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/caps_ref.en5
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/ids_ref.en5
# 1
# /ihome/akovashka/krb115/datasets/translations/translations_ja_to_en_caps_ref.ja1
# /ihome/akovashka/krb115/datasets/translations/ids_ref.ja1
# 2
# /ihome/akovashka/krb115/datasets/extra_ref_sets/translations_ja_to_en_caps_exp_ref.ja2
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/ids_ref.ja2
# 3
# /ihome/akovashka/krb115/datasets/extra_ref_sets/translations_ja_to_en_caps_exp_ref.ja3
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/ids_ref.ja3
# 4
# /ihome/akovashka/krb115/datasets/extra_ref_sets/translations_ja_to_en_caps_exp_ref.ja4
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/ids_ref.ja4
# 5
# /ihome/akovashka/krb115/datasets/extra_ref_sets/translations_ja_to_en_caps_exp_ref.ja5
# /ihome/akovashka/krb115/datasets/custom_coco_stair_splits/ids_ref.ja5
# Lengths
# # Ja Ref Caps: 9666
# # En Ref Caps: 9666
# # En Train Caps: 73117

# %% [markdown]
# ### For each train image, format reference examples into prompt format

# %%
with open(TRAIN_TO_REF_IDX_FILE_PATH, 'rb') as f:
    train_idx_to_ja_ref_idx = pickle.load(f)
train_idx_to_ja_ref_idx[idx]
# Out:
# ['/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000073226.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000430135.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000075829.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000526467.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000344945.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000254821.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000319315.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000385743.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000434145.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000521514.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000053385.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000386127.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000493504.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000295864.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000474401.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000046731.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000047746.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000151170.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000367899.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000301039.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000305422.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000351253.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000127342.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000567389.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000094609.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000558401.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000445906.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000416322.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000354746.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000450777.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000118413.jpg',
#  '/ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000563921.jpg']

# %%
# Load train idx 
with open(TRAIN_TO_REF_IDX_FILE_PATH, 'rb') as f:
    train_idx_to_ja_ref_idx = pickle.load(f)

# Format prompts with reference examples
train_idx_to_formatted_prompt = dict()
for i, idx in enumerate(train_idx_to_ja_ref_idx):

    random_en_index = random.choice(range(len(ALL_JA_REF_CAPS))) + 1
    random_ja_index = random.choice(range(len(ALL_JA_REF_CAPS))) + 1
    
    # Loop through images and get exampl
    list_of_examples = []
    ja_ref_idxs = train_idx_to_ja_ref_idx[idx]
    for ja_ref_idx in ja_ref_idxs[1:]:
        # Get En/Ja captions for each reference format
        ja_ref_cap = ja_ref_idx_to_cap_dict[random_ja_index][ja_ref_idx]
        en_ref_cap = en_ref_idx_to_cap_dict[random_en_index][ja_ref_idx]
        list_of_examples.append(EXAMPLE_FORMAT.format(inp=en_ref_cap, out=ja_ref_cap))
        if len(list_of_examples) == NUM_REF_EXS_TO_USE:
            break
    full_ref_string = "".join(list_of_examples)
    train_idx_to_formatted_prompt[idx] = full_ref_string

# %% [markdown]
# ### Load guidance prompt

# %%
with open(PATH_TO_GUIDE_PROMPT, "r") as f:
    guidance_prompt = "".join(f.readlines())
print(guidance_prompt)
# Out:
# Task Description: For an input image, image caption, and reference input-output caption(s) for similar image(s), rewrite the image caption with similar changes to the style, level of detail, and object term ones made for similar objects in the reference examples. Only perform changes that are correct and semantically relevant to the given input image. After "Output: ", always output a <final> tag, followed by a rewritten caption, then </final>. Never any other text or explanation. One task demo for formatting and change instruction is provided.
#
# Task Demo:
#
# Reference example(s)
# Input: A catcher catching a ball that has just gone by the hitter.
# Output: The batter in the orange uniform just missed the ball.
#
# Inference
# Input: A young boy holding a baseball bat during a baseball game.
# Output: <final> The batter in the grey uniform is waiting for a ball during a game. </final>
#
# Now perform the task exactly as above:
#
# Reference example(s)
# {reference_examples}
#
# Inference
# Input: {input}
# Output:

# %%
prompts = []
image_paths = []
for idx in train_idx_to_cap_dict:
    cap = train_idx_to_cap_dict[idx] 
    prompt = guidance_prompt.format(reference_examples=train_idx_to_formatted_prompt[idx], input=cap)
    prompts.append(prompt)
    image_paths.append(idx)
print(prompts[0])
print(image_paths[0])
print(len(prompts))
print(len(image_paths))
# Out:
# Task Description: For an input image, image caption, and reference input-output caption(s) for similar image(s), rewrite the image caption with similar changes to the style, level of detail, and object term ones made for similar objects in the reference examples. Only perform changes that are correct and semantically relevant to the given input image. After "Output: ", always output a <final> tag, followed by a rewritten caption, then </final>. Never any other text or explanation. One task demo for formatting and change instruction is provided.
#
# Task Demo:
#
# Reference example(s)
# Input: A catcher catching a ball that has just gone by the hitter.
# Output: The batter in the orange uniform just missed the ball.
#
# Inference
# Input: A young boy holding a baseball bat during a baseball game.
# Output: <final> The batter in the grey uniform is waiting for a ball during a game. </final>
#
# Now perform the task exactly as above:
#
# Reference example(s)
# Example:
# 	Input: A woman vendor is sitting outside selling food.
# 	Output: The woman selling things in the store is on the phone
#
#
# Inference
# Input: People shopping in an open market for vegetables.
# Output:
#
# /ix/akovashka/krb115/datasets/COCO-images/train2014/COCO_train2014_000000262145.jpg
# 73117
# 73117

# %% [markdown]
# ### Define parsing helper

# %%
def extract_text_between_final_tags_v2(text):
	start_tag = '<final>'
	end_tag = '</final>'
	start_index = text.find(start_tag)
	if start_index == -1:
		return None
	end_index = text.find(end_tag, start_index)
	if end_index == -1:
		return None
	start_index += len(start_tag)
	return text[start_index:end_index].strip()

# %% [markdown]
# ### Load model

# %%
llm = LLM(
        model=MODEL_TO_USE,
        max_model_len=MAX_MODEL_LEN,
        max_num_seqs=MAXS_NUM_SEQS,
        enforce_eager=INCLUDE_STOP_STR_IN_OUTPUT
    )
sampling_params = SamplingParams(temperature=TEMPERATURE, seed=SEED, stop=STOP_STRING, include_stop_str_in_output=INCLUDE_STOP_STR_IN_OUTPUT, max_tokens=MAX_TOKENS)
# Out:
# WARNING 07-26 10:31:58 config.py:503] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# INFO 07-26 10:31:58 llm_engine.py:249] Initializing an LLM engine (v0.6.4) with config: model='meta-llama/Llama-3.2-11B-Vision-Instruct', speculative_config=None, tokenizer='meta-llama/Llama-3.2-11B-Vision-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=9192, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=meta-llama/Llama-3.2-11B-Vision-Instruct, num_scheduler_steps=1, chunked_prefill_enabled=False multi_step_stream_outputs=True, enable_prefix_caching=False, use_async_output_proc=False, use_cached_outputs=False, chat_template_text_format=string, mm_processor_kwargs=None, pooler_config=None)
# INFO 07-26 10:32:00 selector.py:135] Using Flash Attention backend.
# [W726 10:32:01.849491775 socket.cpp:752] [c10d] The client socket cannot be initialized to connect to [gpu-n35.crc.pitt.edu]:59526 (errno: 97 - Address family not supported by protocol).
# INFO 07-26 10:32:02 model_runner.py:1072] Starting to load model meta-llama/Llama-3.2-11B-Vision-Instruct...
# INFO 07-26 10:32:04 weight_utils.py:243] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/5 [00:00<?, ?it/s]
# INFO 07-26 10:34:29 model_runner.py:1077] Loading model weights took 19.9073 GB
# INFO 07-26 10:34:29 enc_dec_model_runner.py:277] Starting profile run for multi-modal models.
# INFO 07-26 10:34:40 worker.py:232] Memory profiling results: total_gpu_memory=39.38GiB initial_memory_usage=20.56GiB peak_torch_memory=29.38GiB memory_usage_post_profile=20.58Gib non_torch_memory=0.67GiB kv_cache_size=5.39GiB gpu_memory_utilization=0.90
# INFO 07-26 10:34:40 gpu_executor.py:113] # GPU blocks: 2209, # CPU blocks: 1638
# INFO 07-26 10:34:40 gpu_executor.py:117] Maximum concurrency for 9192 tokens per request: 3.85x

# %% [markdown]
# ### Test run for Inference

# %%
BATCH_SIZE = 32

# this is just a test run 
for i in range(0, len(prompts), BATCH_SIZE):
    curr_text_prompts = prompts[i:i+BATCH_SIZE]
    curr_img_paths = image_paths[i:i+BATCH_SIZE]
    curr_imgs = [Image.open(im_path) for im_path in curr_img_paths]
    curr_text_prompts_formatted = [f"<|image|><|begin_of_text|>" + j for j in curr_text_prompts]
    inputs = []
    for j in range(len(curr_imgs)):
        inputs.append({"prompt": curr_text_prompts_formatted[j], 
                        "multi_modal_data": {
                            "image": curr_imgs[j]
                        }, 
                      })
    outputs = llm.generate(inputs, sampling_params=sampling_params)
    break
# Out:
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# WARNING 07-26 10:34:44 preprocess.py:83] Falling back on <BOS> for decoder start token id because decoder start token id is not available.
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:34:44 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# Processed prompts: 100%|██████████| 32/32 [00:15<00:00,  2.04it/s, est. speed input: 510.98 toks/s, output: 37.87 toks/s]

# %% [markdown]
# ### Debug Inference

# %%
SHOW_INDEX = True
SHOW_REF_PROMPT = True
SHOW_INPUT_CAP = True
SHOW_OUT = True
SHOW_IMG = False

for k, o in enumerate(outputs):
    
    im_path = list(train_idx_to_cap_dict.keys())[k]

    # Print stuff
    if SHOW_INDEX:
        print(k)
    if SHOW_REF_PROMPT:
        print(train_idx_to_formatted_prompt[im_path])
    if SHOW_INPUT_CAP:
        print(train_idx_to_cap_dict[im_path])
    if SHOW_OUT:
        print(o.outputs[0].text)
    
    # Read the image
    if SHOW_IMG: 
        img = mpimg.imread(im_path)
        plt.imshow(img)
        plt.axis('off')  # Turn off axis labels
        plt.show()
# Out:
# 0
# Example:
# 	Input: A woman vendor is sitting outside selling food.
# 	Output: The woman selling things in the store is on the phone
#
# People shopping in an open market for vegetables.
# <final> The people shopping in the market are looking at the vegetables. </final>
# 1
# Example:
# 	Input: Man riding a snowboard down a ski slope.
# 	Output: Snowboarder sliding down the slope of a snowy mountain
#
# a person skiing down a steep hill
# <final> Skier sliding down the slope of a snowy mountain </final>
# 2
# Example:
# 	Input: A dog lounges in the grass with its ball.
# 	Output: Black sandals, a black dog walking, and a red and yellow border ball
#
# The black and white dog stands near a person holding a Frisbee.
# <final> The black and white dog stands near a person holding a blue Frisbee. </final>
# 3
# Example:
# 	Input: Man standing on a snowboard on top of an icy mountain.
# 	Output: There is a man on a snowy mountain.
#
# A plane emitting smoke stream flying over a mountain.
# <final> There is a plane flying over a mountain. </final>
# 4
# Example:
# 	Input: The baBY IS PLAYING WITH THE VIDEO GAME CONTROLLER.
# 	Output: Baby holding a game remote
#
# A woman wearing a necklace is brushing her teeth.
# <final> The woman is brushing her teeth. </final>
# 5
# Example:
# 	Input: A man scratches his collar while another man smokes and talks on a phone.
# 	Output: He is a gentleman being targeted by the man behind him.
#
# A man stands with a frown on his face.
# <final> The man in the suit is looking at something with a frown on his face. </final>
# 6
# Example:
# 	Input: An old photo of a little boy with a dog.
# 	Output: A white dog stands next to a dark-skinned boy
#
# A vintage photo of two men and a lama.
# <final> A lama stands next to two dark-skinned men. </final>
# 7
# Example:
# 	Input: A surfer out in the ocean catching a wave
# 	Output: A young foreign male surfer is riding a wave
#
# A man is holding a surfboard and standing in the ocean.
# <final> A young foreign male surfer is waiting for a wave. </final>
# 8
# Example:
# 	Input: A man snowboarding down a snow covered and tree lines hill.
# 	Output: A person snowboarding through snow-covered trees
#
# A man riding skis down a snow covered slope.
# <final> A person skiing through snow-covered trees </final>
# 9
# Example:
# 	Input: A view of a bathroom with a toilet in it.
# 	Output: Toilet paper is provided next to the toilet.
#
# A bathroom with a toilet, sink, and bathtub painted yellow and white.
# <final> The bathroom has a toilet, sink, and bathtub. </final>
# 10
# Example:
# 	Input: Two laptop computers on a bed that seems a bit messy.
# 	Output: There are two laptops on the bed.
#
# A light turned on at a desk with a chair and computer.
# <final> There is a computer on the desk. </final>
# 11
# Example:
# 	Input: There are a lot of sheeps walking together in the grass
# 	Output: Sheep lined up in a row on a rocky meadow
#
# Three goats standing in the middle of a pasture.
# <final> Three goats standing in the middle of a rocky meadow. </final>
# 12
# Example:
# 	Input: Two men standing next to each other with video game controllers in their hands.
# 	Output: Two men standing with game controllers in their hands
#
# A man holding a Wii remote and laughing.
# <final> The man in the brown shirt is holding a Wii remote and laughing. </final>
# 13
# Example:
# 	Input: Two giraffes next to palm tree in outdoor field.
# 	Output: A giraffe is trying to eat leaves from a tree
#
# A giraffe eating food from the top of the tree.
# <final> A giraffe is trying to eat leaves from a tree. </final>
# 14
# Example:
# 	Input: A dead end sign is posted outside of a building with landscaping.
# 	Output: There is a dead end sign in a residential area overgrown with vegetation.
#
# Two traffic signals are posted near the street intersection.
# <final> There are two traffic signals at a busy intersection. </final>
# 15
# Example:
# 	Input: A street corner with trees that are covered in snow.
# 	Output: With many cars stuck in the snow, the traffic lights are lit sadly.
#
# this is a close up picture of a park bench
# <final> The park bench is empty and the trees are bare. </final>
# 16
# Example:
# 	Input: The table in the small apartment is set for one person.
# 	Output: The light in the back room is on and the door is open.
#
# Cardboard boxes piled up in a family living room area
# <final> The window in the back room is open and the door is closed. </final>
# 17
# Example:
# 	Input: A couple of people that are posing for a picture.
# 	Output: Two men standing together wearing straw hats, one in a suit and tie and the other in a dress shirt
#
# A man in a cap dressed in clothing from a past era.
# <final> A man in a cap wearing a dark shirt and tie with a plaid patterned tie. </final>
# 18
# Example:
# 	Input: Several people on skis on a mountain slope.
# 	Output: A man wearing goggles and purple pants, sans gloves
#
# Two people are dressed in ski clothing and wearing skis are sitting on a ski lift.
# <final> The person in the red jacket and black pants is wearing goggles and a helmet. </final>
# 19
# Example:
# 	Input: A couple of statues that are in the grass.
# 	Output: A spooky object playing an accordion
#
# A guy with a big coat and woman looking at him.
# <final> The man in the grey coat is showing off his outfit to the woman in the red dress. </final>
# 20
# Example:
# 	Input: A woman Riding a wave on a surfboard
# 	Output: A woman in a swimsuit is surfing
#
# A woman on a surfboard in the ocean
# <final> A woman in a swimsuit is surfing. </final>
# 21
# Example:
# 	Input: A zebra stands in a field of tall grass.
# 	Output: A zebra stands alone in the grassland
#
# A zebra grazing on lush green grass in a field.
# <final> A zebra is grazing in the grassland. </final>
# 22
# Example:
# 	Input: Two women walk across a street-crossing in a city with cars and a bus driving by.
# 	Output: A bus is running on the road after the rain has stopped
#
# Stop lights hanging from a wire showing green
# <final> The traffic lights are green after the rain has stopped </final>
# 23
# Example:
# 	Input: a woman with an umbrella standing outside on a sunny day
# 	Output: A lightly dressed woman is raising her arm holding an umbrella
#
# Woman in swim suit holding parasol on sunny day.
# <final> A woman in a swimsuit is holding a parasol on a sunny day. </final>
# 24
# Example:
# 	Input: People at the beach sitting on the sand and under umbrellas.
# 	Output: Many people sitting on the beach
#
# A group of people stand underneath bridge of kites.
# <final> A group of people stand underneath a bridge of kites. </final>
# 25
# Example:
# 	Input: A person holding a hot dog wrapped in foil.
# 	Output: The hot dog is topped with ketchup and mustard.
#
# Holding a hot dog in a crumbly bun with a napkin.
# <final> The hot dog is wrapped in a bun with a napkin. </final>
# 26
# Example:
# 	Input: A yellow bulldozer parked near some other trucks in a parking lot.
# 	Output: A yellow bulldozer and a yellow truck are lined up
#
# a couple of big trucks that are next to some water
# <final> A yellow truck and a yellow tractor are parked next to a body of water. </final>
# 27
# Example:
# 	Input: A small white tiled bathroom with wood cabinets
# 	Output: There is a sink in front of the flush toilet
#
# A small bathtub with an old bathroom and sink in it.
# <final> There is a sink in front of the bathtub. </final>
# 28
# Example:
# 	Input: An vintage aircraft that is sitting on the tarmac on display.
# 	Output: The plane is white with a red horizontal line and there is a fence in front of it.
#
# A plane that is on the ground during the day.
# <final> The plane is red with a white stripe and there is a fence in front of it. </final>
# 29
# Example:
# 	Input: a small airplane sitting on the runway
# 	Output: A plane parked at the airport under a blue sky
#
# A couple of airplanes sitting on top of an airport runway.
# <final> A couple of planes parked at the airport under a blue sky. </final>
# 30
# Example:
# 	Input: A motorcycle parked on a sidewalk near a truck and stop sign.
# 	Output: A motorcycle is parked under the sign
#
# A brown teddy bear sitting on top of a blue box.
# <final> A teddy bear is sitting on top of a blue box. </final>
# 31
# Example:
# 	Input: A person riding a horse, jumping it over an obstacle.
# 	Output: You are riding and your horse is trying to overcome an obstacle
#
# A couple of men riding horses on top of a green field.
# <final> The two men are riding horses on top of a green field. </final>

# %%
#with open(OUT_PATH, 'rb') as f:
#    llama_response_dict = pickle.load(f)
#    print('So far: ' + str(len(llama_response_dict)) + ' samples')

# %% [markdown]
# ### Now Run Main Inference

# %%
# Load LLaMA response dictionary in progress
if LOAD_IN_PROGRESS_LLAMA_DICT:
    with open(OUT_PATH, 'rb') as f:
        llama_response_dict = pickle.load(f)
    print('So far: ' + str(len(llama_response_dict)) + ' samples')
else:
    llama_response_dict = dict()    

# Loop through all data
for i in range(0, len(prompts), BATCH_SIZE):

    # Check if we already recaptioned sample 
    if i < len(llama_response_dict):
        continue
        
    # Get current batch of images and text, formatted for LLaMA 3.2
    curr_text_prompts = prompts[i:i+BATCH_SIZE]
    curr_img_paths = image_paths[i:i+BATCH_SIZE]
    curr_imgs = [Image.open(im_path) for im_path in curr_img_paths]
    curr_text_prompts_formatted = [f"<|image|><|begin_of_text|>" + j for j in curr_text_prompts]
    inputs = []
    for j in range(len(curr_imgs)):
        inputs.append({"prompt": curr_text_prompts_formatted[j], 
                        "multi_modal_data": {
                            "image": curr_imgs[j]
                        }, 
                      })

    # Generate outputs for current batch
    outputs = llm.generate(inputs, sampling_params=sampling_params)

    # Write outputs to file
    for i, output in enumerate(outputs):
        generated_text = output.outputs[0].text
        curr_train_id = curr_img_paths[i]
        llama_response_dict[curr_train_id] = dict()
        llama_response_dict[curr_train_id]['ref_prompt'] = curr_text_prompts_formatted[i]
        llama_response_dict[curr_train_id]['full_response'] = generated_text
        llama_response_dict[curr_train_id]['parsed_response'] = extract_text_between_final_tags_v2(generated_text)

    # Write output
    with open(OUT_PATH, 'wb') as f:
        pickle.dump(llama_response_dict, f)
# Out:
# So far: 67136 samples
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:01 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# Processed prompts: 100%|██████████| 32/32 [00:17<00:00,  1.82it/s, est. speed input: 455.19 toks/s, output: 33.80 toks/s]
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:27 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# Processed prompts: 100%|██████████| 32/32 [00:15<00:00,  2.09it/s, est. speed input: 518.82 toks/s, output: 39.42 toks/s]
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:35:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# Processed prompts: 100%|██████████| 32/32 [00:15<00:00,  2.05it/s, est. speed input: 512.99 toks/s, output: 38.39 toks/s]
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:04 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# Processed prompts: 100%|██████████| 32/32 [00:12<00:00,  2.61it/s, est. speed input: 651.66 toks/s, output: 48.15 toks/s]
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:20 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# Processed prompts: 100%|██████████| 32/32 [00:17<00:00,  1.87it/s, est. speed input: 464.91 toks/s, output: 35.55 toks/s]
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 10:36:40 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# ...
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:39:46 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# Processed prompts: 100%|██████████| 32/32 [00:12<00:00,  2.57it/s, est. speed input: 639.62 toks/s, output: 45.62 toks/s]
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# INFO 07-26 11:40:02 preprocess.py:215] Your model uses the legacy input pipeline instead of the new multi-modal processor. Please note that the legacy pipeline will be removed in a future release. For more details, see: https://github.com/vllm-project/vllm/issues/10114
# Processed prompts:   0%|          | 0/29 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]

# %%
# Show example
print(llama_response_dict[curr_train_id])
img = mpimg.imread(curr_train_id)
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.show()

# %% [markdown]
# ### Look at Some Examples

# %%
for i, idx in enumerate(train_ids[:100]):
    print(idx + ';' + train_idx_to_cap_dict[idx] + ';' + str(llama_response_dict[idx]['parsed_response']) + ';' + str(train_idx_to_formatted_prompt[idx].replace("\n","")) + ';' +  str(llama_response_dict[idx]['full_response']).replace("\n",""))
